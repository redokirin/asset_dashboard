# %%
import sys
import os

# 1. 將路徑指向專案根目錄 (確保能讀取 assets_config.py)
project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)

# 2. 直接執行腳本
# %run 會模擬終端機執行，觸發腳本內的 if __name__ == "__main__": 區塊
# 腳本會自動偵測到目前是 Jupyter 環境，並呼叫 show_jupyter()
# %run ../dashboard.py
# Out:
# --- 🌍 全球市場雷達 ---
# <style type="text/css">
# #T_b47ea_row0_col2, #T_b47ea_row1_col2, #T_b47ea_row2_col2, #T_b47ea_row4_col2 {
#   color: green;
# }
# #T_b47ea_row3_col2 {
#   color: red;
# }
# </style>
# <table id="T_b47ea">
#   <thead>
#     <tr>
#       <th id="T_b47ea_level0_col0" class="col_heading level0 col0" >名稱</th>
#       <th id="T_b47ea_level0_col1" class="col_heading level0 col1" >數值</th>
#       <th id="T_b47ea_level0_col2" class="col_heading level0 col2" >漲跌幅</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b47ea_row0_col0" class="data row0 col0" >台灣加權指數</td>
#       <td id="T_b47ea_row0_col1" class="data row0 col1" >33,581.86</td>
#       <td id="T_b47ea_row0_col2" class="data row0 col2" >-1.56%</td>
#     </tr>
#     <tr>
#       <td id="T_b47ea_row1_col0" class="data row1 col0" >S&P500 期貨</td>
#       <td id="T_b47ea_row1_col1" class="data row1 col1" >6,753.00</td>
#       <td id="T_b47ea_row1_col2" class="data row1 col2" >-0.39%</td>
# ...
